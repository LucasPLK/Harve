# %% [markdown]
# # Métricas e python

# %%
from sklearn import metrics
from sklearn.datasets import make_classification, make_regression
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Dataset
# Vamos criar um dataset para classificação e um para regressão

# %%
X_classification, Y_classification = make_classification(n_samples=1000, n_features=4)
X_regression, Y_regression = make_regression(n_samples=1000, n_features=4)

# %% [markdown]
# #### Disclamer:
# Para esse exemplo não estamos preocupados em ter a melhor performance do modelo ou com questões de overfitting/underfitting. Por isso não realizaremos a divisão do dataser em treinamento, teste e validação

# %% [markdown]
# ##Modelos

# %%
classificador = DecisionTreeClassifier(max_depth=3)
regressor = LinearRegression()

# %%
classificador.fit(X_classification, Y_classification)
y_pred_classification = classificador.predict(X_classification)

# %%
regressor.fit(X_regression, Y_regression)
y_pred_regression = regressor.predict(X_regression)

# %% [markdown]
# # Métricas
# vamos aplicar algumas métricas e comparar seus resultados

# %%
metrics.median_absolute_error
metrics.mean_absolute_percentage_error
metrics.mean_squared_error
metrics.accuracy_score
metrics.confusion_matrix
metrics.precision_score
metrics.recall_score
metrics.f1_score
