# %% [markdown]
# # Hands On aula 2:
#
# Utilize o que já aprendeu em seu curso para criar as métricas False Positive Rate e True Positive Rate:
#
# $FPR = \frac{FP}{FP+TN}$
#
# $TPR = \frac{TP}{TP+FN}$
#
# O que a equação do TPR te lembra...?
#
# Desenvolva também o código da métrica MSE:
#
# $MSE = \frac{1}{n}*\sum (y_{pred} - y)^2$

# %% [markdown]
# ## Aplicação:
#
# Escolha um dos datasets do scikit learn e crie um modelo aderente ao problema e aplique suas métricas recém criadas para descobrir se o modelo está bem ajustado.
